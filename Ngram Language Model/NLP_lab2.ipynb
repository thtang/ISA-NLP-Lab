# %% [markdown]
# # 102034038 湯忠憲 NLP Lab2

# %%
#improt API
from NetSpeakAPI import NetSpeak
from LinggleAPI import Linggle

# %%
#Lab1 correction functions
import re, collections

def words(text): return re.findall('[a-z]+', text.lower())

def words_and_bigrams(text):
    all_words = words(text)
    bigrams = [ ' '.join(all_words[i:i+2]) for i in range(len(all_words)-1) ]
    return all_words + bigrams

def train(features):
    model = collections.defaultdict(lambda: 1)
    for f in features:
        model[f] += 1
    return model

NWORDS = train(words_and_bigrams(open('big.txt').read()))

alphabet = 'abcdefghijklmnopqrstuvwxyz'

def edits1(word):
    splits     = [(word[:i], word[i:]) for i in range(len(word) + 1)]
    deletes    = [a + b[1:] for a, b in splits if b]
    transposes = [a + b[1] + b[0] + b[2:] for a, b in splits if len(b)>1]
    replaces   = [a + c + b[1:] for a, b in splits for c in alphabet if b]
    inserts    = [a + c + b     for a, b in splits for c in alphabet+' ' ]
    return set(deletes + transposes + replaces + inserts)

def known_edits2(word):
    return set(e2 for e1 in edits1(word) for e2 in edits1(e1) if e2 in NWORDS)

def known(words): return set(w for w in words if w in NWORDS)

# list all possible fusion error candidate
def fusions_edit(word):
    word        = word.replace(' ', '')
    splits     = [(word[:i], word[i:]) for i in range(len(word) + 1)]
    fusions    = [(a+' '+b) for a, b in splits if a in NWORDS and b in NWORDS]
    if word in NWORDS:
        fusions += [word]
    return fusions

def correct(word):
    candidates = known([word]) or known(edits1(word)) or known_edits2(word) or [word]
    fusions = fusions_edit(word)
    # correct with fusion error first
    if fusions:
        return sorted(fusions, key=NWORDS.get)[:10]
    # correct with edit candidate if no fusion candidate found
    return sorted(candidates, key=NWORDS.get)[:10]

#function to generate candidates for correcting
def generate_candidates(word):
    candidates = known([word]) or known(edits1(word)) or known_edits2(word) or [word] or fusions_edit(word)
    return candidates

# %%
generate_candidates("weanter")
# Out:
# {'banter',
#  'canter',
#  'center',
#  'chanter',
#  'decanter',
#  'easter',
#  'enter',
#  'heater',
#  'planter',
#  'renter',
#  'shanter',
#  'sweater',
#  'venter',
#  'waiter',
#  'walter',
#  'wander',
#  'wanted',
#  'water',
#  'we enter',
#  'weaker',
#  'weaned',
#  'wearer',
#  'weather',
#  'weaver',
#  'webster',
#  'welter',
#  'werner',
#  'wetter',
#  'winter'}

# %% [markdown]
# ### Load testing data here!!

# %%
count = 0
error = []
correct = []
for i in open("lab2.test.1.txt").readlines():
    count += 1
    error.append(i.split("\t")[0])
    correct.append(i.split("\t")[1])
print "number of lines to correct:",count
# Out:
# number of lines to correct: 198

# %% [markdown]
# ### Load confusables text

# %%
confusable_dict = {}
for line in open("lab2.confusables.txt").readlines():
    line_array = line.split("\t")
    confusable_dict[line_array[0]] = line_array[1].strip()
confusable_dict
# Out:
# {'accede': 'exceed',
#  'accept': 'except',
#  'adept': 'adopt',
#  'adverse': 'averse',
#  'advice': 'advise',
#  'affect': 'effect',
#  'aid': 'aide',
#  'airs': 'heirs',
#  'allude': 'elude',
#  'allusion': 'illusion',
#  'almost': 'most',
#  'aloud': 'allowed',
#  'alternately': 'alternatively',
#  'ambiguous': 'ambivalent',
#  'amiable': 'amicable',
#  'among': 'between',
#  'amoral': 'immoral',
#  'amount': 'number',
#  'amused': 'bemused',
#  'an': 'and',
#  'annual': 'annul',
#  'anywheres': 'nowheres',
#  'apart': 'a part',
#  'appraise': 'apprise',
#  'arcane': 'archaic',
#  'as': 'like',
#  'ascent': 'assent',
#  'ascetic': 'aesthetic',
#  'ascribe': 'describe',
#  'aspersion': 'dispersion',
#  'assent': 'ascent',
#  'assistance': 'assistants',
#  'auger': 'augur',
#  'bad': 'badly',
#  'baited': 'bated',
#  'bare': 'bear',
#  'bazaar': 'bizarre',
#  'belief': 'believe',
#  'beside': 'besides',
#  'better': 'had better',
#  'between': 'among',
#  'biannual': 'biennial',
#  'bimonthly': 'semimonthly',
#  'blithe': 'lithe',
#  'blonde': 'blond',
#  'boar': 'boor',
#  'board': 'bored',
#  'born': 'borne',
#  'braise': 'braze',
#  'brake': 'break',
#  'breath': 'breathe',
#  'bridal': 'bridle',
#  'buy': 'bye',
#  'canvas': 'canvass',
#  'capital': 'capitol',
#  'censor': 'censure',
#  'climactic': 'climatic',
#  'co-operation': 'corporation',
#  'coarse': 'course',
#  'collaborate': 'corroborate',
#  'complement': 'compliment',
#  'compose': 'comprise',
#  'concurrent': 'consecutive',
#  'conform': 'confirm',
#  'congenial': 'congenital',
#  'connote': 'denote',
#  'conscience': 'conscious',
#  'continual': 'continuous',
#  'convince': 'persuade',
#  'core': 'corpse',
#  'correspondence': 'correspondents',
#  'counsel': 'consul',
#  'creak': 'creek',
#  'credible': 'creditable',
#  'criteria': 'criterion',
#  'custom': 'costume',
#  'dairy': 'diary',
#  'deduction': 'induction',
#  'denote': 'connote',
#  'describe': 'ascribe',
#  'desert': 'dessert',
#  'device': 'devise',
#  'diary': 'dairy',
#  'dick': 'dig',
#  'discreet': 'discrete',
#  'disinterested': 'uninterested',
#  'dispersion': 'aspersion',
#  'divers': 'diverse',
#  'each': 'every',
#  'effect': 'affect',
#  'elicit': 'illicit',
#  'elude': 'allude',
#  'emanant': 'imminent',
#  'emigrant': 'immigrant',
#  'emigrate': 'immigrate',
#  'enervate': 'innervate',
#  'ensure': 'assure',
#  'entomology': 'etymology',
#  'ethereal': 'ephemeral',
#  'everyone': 'every one',
#  'exceed': 'accede',
#  'except': 'accept',
#  'exclation': 'escalator',
#  'explicit': 'implicit',
#  'fair': 'fare',
#  'farther': 'further',
#  'faze': 'phase',
#  'few': 'less',
#  'figuratively': 'literally',
#  'flammable': 'inflammable',
#  'flare': 'flair',
#  'flaunt': 'flout',
#  'forbear': 'forebear',
#  'foreword': 'forward',
#  'forth': 'fourth',
#  'foul': 'fowl',
#  'found': 'founded',
#  'founder': 'flounder',
#  'gibe': 'gybe',
#  'gorilla': 'guerrilla',
#  'gybe': 'jibe',
#  'hail': 'hale',
#  'hanged': 'hung',
#  'herd': 'heard',
#  'here': 'hear',
#  'heroin': 'heroine',
#  'historic': 'historical',
#  'hoard': 'horde',
#  'hole': 'whole',
#  'home': 'hone',
#  'illicit': 'elicit',
#  'illusion': 'allusion',
#  'immigrant': 'emigrant',
#  'immigrate': 'emigrate',
#  'imminent': 'eminent, emanant',
#  'immoral': 'amoral',
#  'immortal': 'immoral',
#  'implicit': 'explicit',
#  'imply': 'infer',
#  'inchoate': 'incoherent',
#  'incredible': 'incredulous',
#  'induction': 'deduction',
#  'innervate': 'enervate',
#  'intolerable': 'intolerant',
#  'irregardless': 'regardless',
#  'its': "it's",
#  'knew': 'new',
#  'latent': 'patent',
#  'later': 'latter',
#  'lay': 'lie',
#  'lead': 'led',
#  'lend': 'loan',
#  'less': 'few',
#  'lessen': 'lesson',
#  'liable': 'libel',
#  'lightening': 'lightning',
#  'like': 'as',
#  'literally': 'figuratively',
#  'lithe': 'blithe',
#  'loan': 'borrow',
#  'loathe': 'loath',
#  'loose': 'lose',
#  'manner': 'manor',
#  'mantel': 'mantle',
#  'marital': 'martial',
#  'marshal': 'marshall',
#  'me': 'myself',
#  'mete': 'meat',
#  'militate': 'mitigate',
#  'mordant': 'trenchant',
#  'most': 'almost',
#  'mute': 'moot',
#  'no': 'know',
#  'noisome': 'noisy',
#  'nowhere': 'nowheres',
#  'obeisance': 'obsequious',
#  'obtuse': 'abstruse',
#  'overdo': 'overdue',
#  'pamper': 'pander',
#  'passed': 'past',
#  'pasture': 'pastor',
#  'patent': 'latent',
#  'patience': 'patients',
#  'peace': 'piece',
#  'peer': 'pier',
#  'penultimate': 'ultimate',
#  'perspective': 'prospective',
#  'persuade': 'convince',
#  'phase': 'faze',
#  'piquant': 'pique',
#  'pique': 'peak',
#  'plain': 'plane',
#  'pore': 'pore',
#  'portent': 'potent',
#  'practical': 'practicable',
#  'precede': 'proceed',
#  'premise': 'premises',
#  'presence': 'presents',
#  'principal': 'principle',
#  'profit': 'prophet',
#  'profligate': 'prolific',
#  'quiet': 'quite',
#  'quote': 'quotation',
#  'raise': 'raze',
#  'real': 'really',
#  'reality': 'realty',
#  'rebate': 'refund',
#  'regimen': 'regiment',
#  'reign': 'rein',
#  'residence': 'residents',
#  'respectful': 'respective',
#  'respectfully': 'respectively',
#  'restive': 'restful',
#  'retch': 'wretch',
#  'rifle': 'riffle',
#  'rise': 'raise',
#  'rite': 'write',
#  'road': 'rode',
#  'role': 'roll',
#  'sale': 'sell',
#  'sanguine': 'saturnine',
#  'scene': 'seen',
#  'seam': 'seem',
#  'semimonthly': 'bimonthly',
#  'sensor': 'censure',
#  'sensual': 'sensuous',
#  'serf': 'surf',
#  'sever': 'severe',
#  'shear': 'sheer',
#  'shore': 'sure',
#  'sight': 'cite',
#  'singly': 'singularly',
#  'sit': 'seat',
#  'site': 'sight',
#  'sleight-of-hand': 'slight-of-hand',
#  'sole': 'soul',
#  'sometime': 'sometimes',
#  'stationary': 'stationery',
#  'statute': 'stature',
#  'storey': 'story',
#  'straight': 'strait',
#  'supposedly': 'supposably',
#  'taut': 'taught',
#  'tenant': 'tenet',
#  'than': 'then',
#  'themself': 'themselves',
#  'there': "they're",
#  'threw': 'through',
#  'throes': 'throws',
#  'til': 'till',
#  'too': 'two',
#  'torpid': 'turgid',
#  'tortuous': 'torturous',
#  'undoubtably': 'indubitably',
#  'uninterested': 'disinterested',
#  'vain': 'vein',
#  'venal': 'venial',
#  'verses': 'versus',
#  'vicious': 'viscous',
#  'waight': 'waits',
#  'waist': 'waste',
#  'wary': 'weary',
#  'wave': 'waive',
#  'weak': 'week',
#  'weather': 'whether',
#  'were': "we're",
#  'wet': 'whet',
#  'which': 'witch',
#  "who's": 'whose',
#  'wont': "won't",
#  'your': "you're"}

# %%
confusable_dict["amused"]
# Out:
# 'bemused'

# %% [markdown]
# ### normalize text

# %%
clean_error = [string.strip().lower().replace(".","") for string in error]
clean_error
# Out:
# ['i felt very strang',
#  'at brake time',
#  'when the brack was finished',
#  'in the weanter when it was snowing',
#  'i thought it was a gost',
#  'everything expect the houses',
#  'when i first steped',
#  'and saw streagh colow people',
#  'and saw streagh colow people',
#  'i was on an exclation',
#  'i noicey that i was on this thing',
#  'through the fance',
#  'the hunters kille them',
#  'they kill birds with their nerrow',
#  'make a depe hole',
#  'to tidy up his gardon',
#  'the wind belu the leaves',
#  'mr j was very angray',
#  'garden full of leavs',
#  'talk to the manger',
#  'they throw a aero',
#  'an ansion method of hunting',
#  'after the dear',
#  'the birds flu up',
#  'making any noice',
#  'bring it stright to the hunters',
#  'this menes a man waits',
#  'a man waight for the animal',
#  'an arow in his hand',
#  'they dick a hole',
#  'a pice of bait',
#  'this tarpp looks like a cave',
#  'they make nose',
#  'the animals are skeard',
#  'the ribbetes will run',
#  'they throw stons',
#  'they chaching the animals',
#  'three handred people',
#  'it was coulorful',
#  'i saw many crowns',
#  'could do it easly',
#  'blood was comming out',
#  'you have wondered away',
#  'you can controle with your toes',
#  'chating to each other',
#  'out from the wardrope',
#  'for controlling temerature',
#  'friendly with your neibours',
#  'the prinsess has given birth',
#  'to make arrengiments',
#  'hit him with a hamer',
#  'they mite see you',
#  'transport is deferent',
#  'they have different cloves',
#  'a plastic sharpner',
#  'the chinease invented paper',
#  'a bottal of lemonade',
#  'to here you',
#  'on and of',
#  'if you are thisty',
#  'a march box',
#  'all of a sarden',
#  'went up the certon',
#  'with babbles in it',
#  'so i had a barth',
#  'i made clouths with it',
#  'i was skeard of it',
#  'throw the window',
#  'one of my exsiting days',
#  'found some crames and ate them',
#  'i was very carful',
#  'speaking to a gost',
#  'to mak people scared',
#  'lit a candel',
#  'a man or a laddy',
#  'something bard happened',
#  'thander and lightning',
#  'the inspector, the sargent',
#  'a light and a nose',
#  'i would rube a rag',
#  'cruch a police car',
#  'ian triped over',
#  'got a tuisse from her bag',
#  'want do you mean',
#  "i'm writting a letter",
#  'a straigt line',
#  'i througt it was going to rain',
#  'he just whated to die',
#  'bounsing a ball',
#  'ate some fruts',
#  "he doesn't noteics",
#  'a bull charcing at him',
#  'and ice-cream stroe',
#  'there was a girrife',
#  'then a circodile came',
#  'iorn is a hard metal',
#  'four pen kives',
#  'there are four chimmys',
#  'on the blackbroad',
#  'on the golb',
#  'in the cupbroad',
#  'the light swith',
#  'from the thinest',
#  'to the fatest',
#  'in a feild',
#  'a cerry red dress',
#  'the being of the play',
#  'fried rice and nodles',
#  'carry money whith me',
#  'they are belive superstitious',
#  'the things i belive',
#  'differences between their knowledg',
#  'by logical speach',
#  'a white coulor',
#  "don't make anything beark",
#  'to feind out',
#  'when a cuple',
#  'the dustpin is being emptyed',
#  'the dustpin is being emptyed',
#  'the roof is being repared',
#  'have to be emtied every day',
#  'they where cleaned',
#  'he belive in the old story',
#  'the most fameous player',
#  'of the centery',
#  'the man had tired to smuggle',
#  'put more petroil',
#  'he tryed to',
#  'heard a extrange noise',
#  'he tryed to',
#  'he hited him',
#  "he'd forgoten to",
#  "he'd setted fire to",
#  "he'd shooted his wife",
#  'sent them to prision',
#  'craying her eyes out',
#  'las monday',
#  'put on weigh',
#  'what had happend',
#  "he'd safed the woman",
#  'becom too fat',
#  'what had happend',
#  'in hollidays today',
#  'photographes of footprints',
#  'wich cannot be explained',
#  "it's a wolfe",
#  "they aren't discoverd",
#  'to photographe these things',
#  'an unborne child',
#  'the misterious beach',
#  'chosing between',
#  'it rapresents the',
#  'it is ridicolous that',
#  'is scientificly proved',
#  'there are advertisments for',
#  'it was my immagination',
#  'to bann smoking',
#  'my happyness depends on',
#  'the pleasent smell of',
#  'dialing the number',
#  'actualy i had no',
#  'the most tireing part',
#  'gamblers play pocker',
#  'the existance of',
#  'phisical sensations',
#  'it is without doupt',
#  'let us analize',
#  'devlopping countries',
#  'i personnaly believe',
#  'as often as i breath',
#  'flowers, perfums',
#  "to interprete what i've said",
#  'my stomache hurt',
#  'surprised and paralised by',
#  'i belief it was',
#  'when it occured',
#  'she asked us wether',
#  'an extremly hot day',
#  'be able to chose',
#  'their oppinion about',
#  'to think wat',
#  'to contenue with',
#  'it was quiet successful',
#  'i never thout that',
#  "i'd heart that",
#  'he obvisicly reckoned',
#  'to prays him',
#  'screeming louder than',
#  'to absorbe it',
#  "i couldn't stop starring",
#  'a street caffe',
#  'a movie was showen',
#  'companys started to work',
#  'their is',
#  'a tendancy to',
#  'meet in the snak-bar',
#  'security controll',
#  'in condact with']

# %% [markdown]
# ### My Correction function !

# %%
def ngram_correction(test, ngram = 3): #input a list of word and n-gram
    for i in range(len(test) - ngram+1):
        candidate_count = []
        for position, word in enumerate(test[i:i + ngram]):
            candidates = list(generate_candidates(word))
            if word in confusable_dict:
                candidates.append(confusable_dict[word])            
            for candidate in candidates:
                #print (position,candidate)
                input_string = test[i:i + ngram]
                input_string[position] = candidate
                #print "search string:",' '.join(input_string)
                res = SE.search(' '.join(input_string))
                if res:
                    #print res
                    candidate_count.append(res[0])
                else:
                    print('not found')
        try:
            
            max_count_bigram_output = sorted(candidate_count,key=itemgetter(1),reverse= True)[0][0]
            print max_count_bigram_output
            if i ==0:
                #print "cccccandate:", max_count_bigram_output.split()
                correct_sentence.append(max_count_bigram_output)
            else:
                #print "cccccandate:", max_count_bigram_output.split()[1]
                correct_sentence.append(max_count_bigram_output.split()[ngram-1])
        # If Linggle can not find at least one new word combination, just concatenate the original words
        except:
            if i ==0:
                correct_sentence.append(" ".join(test[i:i + ngram]))
            else:
                correct_sentence.append(test[i+ngram-1])

# %%
from operator import itemgetter
#SE = NetSpeak()
SE = Linggle()
final_output = []
count = 0
for sentence in error:
    test = sentence.lower().split()
    correct_sentence  = []
    
    # if error string has more than two words, use trigram
    if len(test)>2:     
        ngram_correction(test, ngram = 3)
        
    # use bigram if only two words
    else:
        ngram_correction(test, ngram = 2)
    print " ".join(correct_sentence)
    final_output.append(" ".join(correct_sentence))
# Out:
# i felt very
# not found
# not found
# not found
# i felt very strang
# not found
# not found
# not found
# at break time
# at break time
# not found
# not found
# not found
# not found
# when the black
# not found
# not found
# not found
# not found
# the track was
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# track was finished
# when the black was finished
# not found
# not found
# not found
# not found
# not found
# in the center
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# the water when
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# water when it
# when it was
# it was snowing
# in the center when it was snowing
# i thought it
# thought it was
# it was a
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# was a most
# i thought it was a most
# everything expect the
# expect the houses
# everything expect the houses
# when i first
# not found
# not found
# not found
# not found
# not found
# not found
# i first stepped
# when i first stepped
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# and saw streaks
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# and saw streaks colow people
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# and saw streaks
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# and saw streaks colow people
# i was on
# was on an
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# on an exception
# i was on an exception
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# i noticed that
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# noticed that i
# that i was
# i was on
# was on this
# on this thing
# i noticed that i was on this thing
# not found
# not found
# not found
# not found
# not found
# through the fence
# through the fence
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# the hunters killed
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# hunters kill them
# the hunters killed them
# they kill birds
# kill birds with
# birds with their
# not found
# not found
# with their narrow
# they kill birds with their narrow
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# make a deep
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# a deep hole
# make a deep hole
# to tidy up
# tidy up his
# not found
# not found
# not found
# not found
# not found
# not found
# up his garden
# to tidy up his garden
# not found
# not found
# not found
# not found
# not found
# the wind belt
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# the wind belt the leaves
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# was very angry
# mr j. was very angry
# garden full of
# not found
# not found
# not found
# not found
# full of leaves
# garden full of leaves
# talk to the
# to the manger
# talk to the manger
# they throw a
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# throw a hero
# they throw a hero
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# method of hunting
# an ansion method of hunting
# after the dear
# after the dear
# not found
# not found
# not found
# not found
# not found
# not found
# the birds flu up
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# making any noise
# making any noise
# not found
# not found
# bring it straight
# it straight to
# straight to the
# to the hunters
# bring it straight to the hunters
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# a man waits
# this menes a man waits
# not found
# not found
# not found
# not found
# a man waits
# not found
# not found
# not found
# not found
# not found
# man waits for
# not found
# not found
# not found
# waits for the
# for the animal
# a man waits for the animal
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# an arrow in
# not found
# not found
# not found
# not found
# row in his
# in his hand
# an arrow in his hand
# not found
# not found
# not found
# they dig a
# not found
# not found
# not found
# dig a hole
# they dig a hole
# not found
# not found
# not found
# not found
# a piece of
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# piece of bait
# a piece of bait
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# looks like a
# like a cave
# this tarpp looks like a cave
# not found
# not found
# not found
# they make nose
# the animals are
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# animals are heard
# the animals are heard
# not found
# not found
# the diabetes will
# not found
# not found
# not found
# the diabetes will run
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# they throw stones
# they throw stones
# not found
# not found
# not found
# not found
# not found
# not found
# they chaching the animals
# not found
# not found
# not found
# not found
# three hundred people
# three hundred people
# not found
# not found
# it was colorful
# it was colorful
# i saw many
# not found
# not found
# not found
# i saw many crowns
# could do it
# do it easily
# could do it easily
# not found
# not found
# not found
# not found
# blood was coming
# not found
# was coming out
# blood was coming out
# you have wondered
# have wondered away
# you have wondered away
# not found
# you can control
# not found
# not found
# not found
# can control with
# not found
# not found
# not found
# control with your
# not found
# with your toes
# you can control with your toes
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# chatting to each
# to each other
# chatting to each other
# out from the
# not found
# not found
# not found
# from the wardrobe
# out from the wardrobe
# not found
# not found
# for controlling temperature
# for controlling temperature
# not found
# friendly with your
# not found
# not found
# not found
# with your neighbours
# friendly with your neighbours
# not found
# not found
# the princess has
# not found
# not found
# princess has given
# has given birth
# the princess has given birth
# not found
# not found
# to make arrangements
# to make arrangements
# hit him with
# him with a
# not found
# with a hammer
# hit him with a hammer
# not found
# not found
# not found
# mite see you
# they mite see you
# not found
# not found
# not found
# transport is deferent
# they have different
# not found
# not found
# not found
# they have different cloves
# not found
# not found
# not found
# a plastic sharpner
# not found
# not found
# the chinese invented
# not found
# not found
# not found
# the chinese invented paper
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# a total of
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# bottle of lemonade
# a total of lemonade
# to hear you
# to hear you
# on and of
# on and of
# if you are
# not found
# not found
# not found
# you are thirsty
# if you are thirsty
# not found
# not found
# not found
# a march box
# all of a
# not found
# not found
# not found
# not found
# not found
# of a garden
# all of a garden
# went up the
# not found
# not found
# not found
# not found
# went up the certon
# not found
# not found
# not found
# not found
# not found
# not found
# with bubbles in
# not found
# not found
# not found
# not found
# not found
# bubbles in it
# with bubbles in it
# so i had
# i had a
# not found
# not found
# not found
# so i had a barth
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# i made clouths with it
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# i was heard
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# was heard of
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# heard of it
# i was heard of it
# throw the window
# throw the window
# one of my
# not found
# not found
# of my existing
# not found
# not found
# not found
# not found
# one of my existing days
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# some frames and
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# and ate them
# found some crames and ate them
# i was very
# not found
# not found
# was very careful
# i was very careful
# speaking to a
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# to a post
# speaking to a post
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# to make people
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# make people scared
# to make people scared
# not found
# not found
# not found
# lit a candle
# lit a candle
# a man or
# man or a
# not found
# not found
# not found
# not found
# or a lady
# a man or a lady
# not found
# not found
# not found
# something bard happened
# not found
# not found
# not found
# thunder and lightning
# thunder and lightning
# not found
# not found
# the inspector the
# not found
# not found
# not found
# the inspector the sargent
# a light and
# light and a
# and a nose
# a light and a nose
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# i would rube a rag
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# a police car
# cruch a police car
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# ian triped over
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# from her bag
# got a tuisse from her bag
# want do you
# do you mean
# want do you mean
# not found
# not found
# not found
# not found
# not found
# im writting a
# not found
# writing a letter
# im writting a letter
# not found
# not found
# a straight line
# a straight line
# not found
# not found
# i through it
# not found
# not found
# through it was
# it was going
# was going to
# going to rain
# i through it was going to rain
# not found
# not found
# he just hated
# not found
# not found
# just hated to
# not found
# not found
# hated to die
# he just hated to die
# not found
# not found
# bouncing a ball
# bouncing a ball
# not found
# not found
# not found
# ate some fruits
# ate some fruits
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# he doesn't noteics
# not found
# not found
# not found
# not found
# not found
# not found
# a bull charging
# not found
# not found
# not found
# not found
# not found
# not found
# bull charging at
# not found
# not found
# not found
# not found
# not found
# not found
# charging at him
# a bull charging at him
# not found
# not found
# not found
# not found
# not found
# not found
# and ice-cream stroe
# not found
# there was a
# not found
# not found
# was a girlie
# there was a girlie
# not found
# not found
# then a crocodile
# not found
# not found
# a crocodile came
# then a crocodile came
# not found
# not found
# iron is a
# is a hard
# a hard metal
# iron is a hard metal
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# four pen kives
# not found
# there are four
# not found
# not found
# not found
# not found
# not found
# there are four chimmys
# not found
# not found
# not found
# on the blackboard
# on the blackboard
# not found
# not found
# not found
# on the golf
# on the golf
# not found
# not found
# in the cupboard
# in the cupboard
# not found
# not found
# not found
# not found
# not found
# not found
# the light switch
# the light switch
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# from the finest
# from the finest
# not found
# not found
# not found
# to the latest
# to the latest
# not found
# in a field
# in a field
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# a cherry red
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# cherry red dress
# a cherry red dress
# the being of
# being of the
# of the play
# the being of the play
# fried rice and
# not found
# not found
# not found
# not found
# not found
# fried rice and nodles
# not found
# not found
# not found
# not found
# not found
# carry money with
# not found
# not found
# not found
# not found
# not found
# not found
# money with me
# carry money with me
# not found
# not found
# not found
# they are believe
# not found
# not found
# not found
# not found
# they are believe superstitious
# the things i
# not found
# not found
# not found
# things i believe
# the things i believe
# differences between their
# not found
# not found
# not found
# between their knowledge
# differences between their knowledge
# not found
# not found
# not found
# not found
# by logical speach
# not found
# not found
# not found
# a white color
# a white color
# not found
# not found
# dont make anything
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# dont make anything beark
# not found
# not found
# not found
# to feind out
# not found
# not found
# when a couple
# when a couple
# not found
# not found
# not found
# the dustbin is
# not found
# not found
# not found
# not found
# not found
# not found
# is being emptied
# the dustbin is being emptied
# not found
# not found
# not found
# the dustbin is
# not found
# not found
# not found
# not found
# not found
# not found
# is being emptied
# the dustbin is being emptied
# the roof is
# roof is being
# not found
# not found
# is being prepared
# the roof is being prepared
# have to be
# not found
# not found
# to be emptied
# not found
# not found
# be emptied every
# not found
# not found
# emptied every day
# have to be emptied every day
# not found
# not found
# not found
# they where cleaned
# not found
# he believe in
# believe in the
# in the old
# the old story
# he believe in the old story
# not found
# not found
# not found
# the most famous
# not found
# not found
# not found
# most famous player
# the most famous player
# not found
# not found
# of the century
# of the century
# the man had
# not found
# not found
# not found
# had tired to
# not found
# not found
# not found
# the man had tired to smuggle
# not found
# not found
# put more petrol
# put more petrol
# he tried to
# he tried to
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# heard a strange
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# a strange noise
# heard a strange noise
# he tried to
# he tried to
# not found
# not found
# not found
# not found
# he hated him
# he hated him
# not found
# not found
# not found
# not found
# not found
# not found
# he'd forgoten to
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# he'd setted fire to
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# shouted his wife
# he'd shooted his wife
# sent them to
# not found
# not found
# them to prison
# sent them to prison
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# crying her eyes
# her eyes out
# crying her eyes out
# not found
# not found
# las monday
# not found
# not found
# not found
# put on weigh
# not found
# what had happened
# what had happened
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# saved the woman
# he'd safed the woman
# not found
# not found
# not found
# become too fat
# become too fat
# not found
# what had happened
# what had happened
# not found
# not found
# not found
# in hollidays today
# not found
# not found
# not found
# not found
# not found
# photographs of footprints
# photographs of footprints
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# cannot be explained
# wich cannot be explained
# not found
# not found
# not found
# it's a wolfe
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# they aren't discoverd
# not found
# not found
# not found
# not found
# not found
# not found
# to photograph these
# not found
# not found
# not found
# not found
# not found
# not found
# photograph these things
# to photograph these things
# not found
# not found
# not found
# an unborn child
# an unborn child
# not found
# not found
# not found
# the misterious beach
# not found
# choosing between
# choosing between
# not found
# not found
# it represents the
# it represents the
# not found
# not found
# it is ridiculous
# not found
# not found
# is ridiculous that
# it is ridiculous that
# not found
# not found
# not found
# is scientifically proved
# is scientifically proved
# not found
# there are advertisements
# are advertisements for
# there are advertisements for
# it was my
# not found
# not found
# was my imagination
# it was my imagination
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# to ban smoking
# to ban smoking
# not found
# not found
# my happiness depends
# not found
# not found
# happiness depends on
# my happiness depends on
# not found
# not found
# the pleasant smell
# pleasant smell of
# the pleasant smell of
# dialing the number
# dialing the number
# not found
# not found
# not found
# actually i had
# i had no
# actually i had no
# not found
# not found
# not found
# the most tiring
# not found
# not found
# not found
# most tiring part
# the most tiring part
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# gamblers play pocker
# the existence of
# the existence of
# not found
# physical sensations
# physical sensations
# it is without
# not found
# not found
# is without doubt
# it is without doubt
# not found
# not found
# let us analyze
# let us analyze
# not found
# developing countries
# developing countries
# not found
# not found
# not found
# not found
# i personally believe
# i personally believe
# not found
# as often as
# often as i
# not found
# as i breathe
# as often as i breathe
# not found
# not found
# not found
# flowers, perfums
# not found
# not found
# not found
# to interpret what
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# what have said
# to interpret what i've said
# not found
# my stomach hurt
# my stomach hurt
# not found
# not found
# not found
# not found
# not found
# and paralysed by
# surprised and paralised by
# not found
# not found
# not found
# i believe it
# believe it was
# i believe it was
# when it occurred
# when it occurred
# she asked us
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# asked us whether
# she asked us whether
# an extremely hot
# not found
# not found
# extremely hot day
# an extremely hot day
# be able to
# able to chose
# be able to chose
# their opinion about
# their opinion about
# to think wat
# to think wat
# not found
# not found
# not found
# to continue with
# to continue with
# it was quite
# not found
# not found
# not found
# was quite successful
# it was quite successful
# not found
# not found
# not found
# not found
# not found
# not found
# i never thout that
# not found
# not found
# not found
# not found
# i'd heart that
# not found
# not found
# not found
# he obvisicly reckoned
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# not found
# to pray him
# to pray him
# not found
# not found
# not found
# not found
# screaming louder than
# screaming louder than
# not found
# not found
# not found
# not found
# not found
# to absorb it
# to absorb it
# not found
# not found
# not found
# not found
# i could not stop
# not found
# not found
# not found
# not found
# not found
# could not stop starring
# i could not stop stop
# not found
# not found
# a street cafe
# a street cafe
# a movie was
# not found
# not found
# not found
# not found
# not found
# movie was shown
# a movie was shown
# not found
# not found
# not found
# company started to
# started to work
# company started to work
# their is
# their is
# a tendency to
# a tendency to
# meet in the
# not found
# not found
# not found
# meet in the snak-bar
# not found
# security controls
# security controls
# not found
# not found
# in contact with
# in contact with

# %% [markdown]
# Basically, I compute overlapping 3-gram count of candidates to select the best correction. However, some of the sentenses have only two word. Therefore, I use bigram instead of 3-gram and compute count of candidates. If **Linggle** can not find at least one new words combination, I just concatenate the origin sub-string to the correction sentence. In terms of candidates, I extend the big.txt and include confusable words as well.

# %% [markdown]
# ### correction output

# %%
final_output
# Out:
# [u'i felt very strang',
#  u'at break time',
#  u'when the black was finished',
#  u'in the center when it was snowing',
#  u'i thought it was a most',
#  u'everything expect the houses',
#  u'when i first stepped',
#  u'and saw streaks colow people',
#  u'and saw streaks colow people',
#  u'i was on an exception',
#  u'i noticed that i was on this thing',
#  u'through the fence',
#  u'the hunters killed them',
#  u'they kill birds with their narrow',
#  u'make a deep hole',
#  u'to tidy up his garden',
#  u'the wind belt the leaves',
#  u'mr j. was very angry',
#  u'garden full of leaves',
#  u'talk to the manger',
#  u'they throw a hero',
#  u'an ansion method of hunting',
#  u'after the dear',
#  'the birds flu up',
#  u'making any noise',
#  u'bring it straight to the hunters',
#  u'this menes a man waits',
#  u'a man waits for the animal',
#  u'an arrow in his hand',
#  u'they dig a hole',
#  u'a piece of bait',
#  u'this tarpp looks like a cave',
#  'they make nose',
#  u'the animals are heard',
#  u'the diabetes will run',
#  u'they throw stones',
#  'they chaching the animals',
#  u'three hundred people',
#  u'it was colorful',
#  u'i saw many crowns',
#  u'could do it easily',
#  u'blood was coming out',
#  u'you have wondered away',
#  u'you can control with your toes',
#  u'chatting to each other',
#  u'out from the wardrobe',
#  u'for controlling temperature',
#  u'friendly with your neighbours',
#  u'the princess has given birth',
#  u'to make arrangements',
#  u'hit him with a hammer',
#  u'they mite see you',
#  'transport is deferent',
#  u'they have different cloves',
#  'a plastic sharpner',
#  u'the chinese invented paper',
#  u'a total of lemonade',
#  u'to hear you',
#  u'on and of',
#  u'if you are thirsty',
#  'a march box',
#  u'all of a garden',
#  u'went up the certon',
#  u'with bubbles in it',
#  u'so i had a barth',
#  'i made clouths with it',
#  u'i was heard of it',
#  u'throw the window',
#  u'one of my existing days',
#  u'found some crames and ate them',
#  u'i was very careful',
#  u'speaking to a post',
#  u'to make people scared',
#  u'lit a candle',
#  u'a man or a lady',
#  'something bard happened',
#  u'thunder and lightning',
#  u'the inspector the sargent',
#  u'a light and a nose',
#  'i would rube a rag',
#  u'cruch a police car',
#  'ian triped over',
#  u'got a tuisse from her bag',
#  u'want do you mean',
#  u'im writting a letter',
#  u'a straight line',
#  u'i through it was going to rain',
#  u'he just hated to die',
#  u'bouncing a ball',
#  u'ate some fruits',
#  "he doesn't noteics",
#  u'a bull charging at him',
#  'and ice-cream stroe',
#  u'there was a girlie',
#  u'then a crocodile came',
#  u'iron is a hard metal',
#  'four pen kives',
#  u'there are four chimmys',
#  u'on the blackboard',
#  u'on the golf',
#  u'in the cupboard',
#  u'the light switch',
#  u'from the finest',
#  u'to the latest',
#  u'in a field',
#  u'a cherry red dress',
#  u'the being of the play',
#  u'fried rice and nodles',
#  u'carry money with me',
#  u'they are believe superstitious',
#  u'the things i believe',
#  u'differences between their knowledge',
#  'by logical speach',
#  u'a white color',
#  u'dont make anything beark',
#  'to feind out',
#  u'when a couple',
#  u'the dustbin is being emptied',
#  u'the dustbin is being emptied',
#  u'the roof is being prepared',
#  u'have to be emptied every day',
#  'they where cleaned',
#  u'he believe in the old story',
#  u'the most famous player',
#  u'of the century',
#  u'the man had tired to smuggle',
#  u'put more petrol',
#  u'he tried to',
#  u'heard a strange noise',
#  u'he tried to',
#  u'he hated him',
#  "he'd forgoten to",
#  "he'd setted fire to",
#  u"he'd shooted his wife",
#  u'sent them to prison',
#  u'crying her eyes out',
#  'las monday',
#  'put on weigh',
#  u'what had happened',
#  u"he'd safed the woman",
#  u'become too fat',
#  u'what had happened',
#  'in hollidays today',
#  u'photographs of footprints',
#  u'wich cannot be explained',
#  "it's a wolfe",
#  "they aren't discoverd",
#  u'to photograph these things',
#  u'an unborn child',
#  'the misterious beach',
#  u'choosing between',
#  u'it represents the',
#  u'it is ridiculous that',
#  u'is scientifically proved',
#  u'there are advertisements for',
#  u'it was my imagination',
#  u'to ban smoking',
#  u'my happiness depends on',
#  u'the pleasant smell of',
#  u'dialing the number',
#  u'actually i had no',
#  u'the most tiring part',
#  'gamblers play pocker',
#  u'the existence of',
#  u'physical sensations',
#  u'it is without doubt',
#  u'let us analyze',
#  u'developing countries',
#  u'i personally believe',
#  u'as often as i breathe',
#  'flowers, perfums',
#  u"to interpret what i've said",
#  u'my stomach hurt',
#  u'surprised and paralised by',
#  u'i believe it was',
#  u'when it occurred',
#  u'she asked us whether',
#  u'an extremely hot day',
#  u'be able to chose',
#  u'their opinion about',
#  u'to think wat',
#  u'to continue with',
#  u'it was quite successful',
#  'i never thout that',
#  "i'd heart that",
#  'he obvisicly reckoned',
#  u'to pray him',
#  u'screaming louder than',
#  u'to absorb it',
#  u'i could not stop stop',
#  u'a street cafe',
#  u'a movie was shown',
#  u'company started to work',
#  u'their is',
#  u'a tendency to',
#  u'meet in the snak-bar',
#  u'security controls',
#  u'in contact with']

# %% [markdown]
# ### normalize groundtruth text for comparison

# %%
cleaned_correct = []
for string in correct:
    cleaned_correct.append(string.strip().lower().replace(".",""))
cleaned_correct
# Out:
# ['i felt very strange',
#  'at break time',
#  'when the break was finished',
#  'in the winter when it was snowing',
#  'i thought it was a ghost',
#  'everything except the houses',
#  'when i first stepped',
#  'and saw strange colow people',
#  'and saw streagh coloured people',
#  'i was on an escalator',
#  'i noticed that i was on this thing',
#  'through the fence',
#  'the hunters kill them',
#  'they kill birds with their arrow',
#  'make a deep hole',
#  'to tidy up his garden',
#  'the wind blew the leaves',
#  'mr j was very angry',
#  'garden full of leaves',
#  'talk to the manager',
#  'they throw a arrow',
#  'an ancient method of hunting',
#  'after the deer',
#  'the birds flew up',
#  'making any noise',
#  'bring it straight to the hunters',
#  'this means a man waits',
#  'a man waits for the animal',
#  'an arrow in his hand',
#  'they dig a hole',
#  'a piece of bait',
#  'this trap looks like a cave',
#  'they make noise',
#  'the animals are scared',
#  'the rabbits will run',
#  'they throw stones',
#  'they chasing the animals',
#  'three hundred people',
#  'it was colourful',
#  'i saw many clowns',
#  'could do it easily',
#  'blood was coming out',
#  'you have wandered away',
#  'you can control with your toes',
#  'chatting to each other',
#  'out from the wardrobe',
#  'for controlling temperature',
#  'friendly with your neighbours',
#  'the princess has given birth',
#  'to make arrangements',
#  'hit him with a hammer',
#  'they might see you',
#  'transport is different',
#  'they have different clothes',
#  'a plastic sharpener',
#  'the chinese invented paper',
#  'a bottle of lemonade',
#  'to hear you',
#  'on and off',
#  'if you are thirsty',
#  'a match box',
#  'all of a sudden',
#  'went up the curtain',
#  'with bubbles in it',
#  'so i had a bath',
#  'i made clothes with it',
#  'i was scared of it',
#  'through the window',
#  'one of my exciting days',
#  'found some crumbs and ate them',
#  'i was very careful',
#  'speaking to a ghost',
#  'to make people scared',
#  'lit a candle',
#  'a man or a lady',
#  'something bad happened',
#  'thunder and lightning',
#  'the inspector, the sergeant',
#  'a light and a noise',
#  'i would rub a rag',
#  'crush a police car',
#  'ian tripped over',
#  'got a tissue from her bag',
#  'what do you mean',
#  "i'm writing a letter",
#  'a straight line',
#  'i thought it was going to rain',
#  'he just wanted to die',
#  'bouncing a ball',
#  'ate some fruits',
#  "he doesn't notice",
#  'a bull charging at him',
#  'and ice-cream stall',
#  'there was a giraffe',
#  'then a crocodile came',
#  'iron is a hard metal',
#  'four pen knives',
#  'there are four chimneys',
#  'on the blackboard',
#  'on the globe',
#  'in the cupboard',
#  'the light switch',
#  'from the thinnest',
#  'to the fattest',
#  'in a field',
#  'a cherry red dress',
#  'the beginning of the play',
#  'fried rice and noodles',
#  'carry money with me',
#  'they are believe superstitious',
#  'the things i believe',
#  'differences between their knowledge',
#  'by logical speech',
#  'a white colour',
#  "don't make anything break",
#  'to find out',
#  'when a couple',
#  'the dustbin is being emptyed',
#  'the dustpin is being emptied',
#  'the roof is being repaired',
#  'have to be emptied every day',
#  'they were cleaned',
#  'he believes in the old story',
#  'the most famous player',
#  'of the century',
#  'the man had tried to smuggle',
#  'put more petrol',
#  'he tried to',
#  'heard a strange noise',
#  'he tried to',
#  'he hit him',
#  "he'd forgotten to",
#  "he'd set fire to",
#  "he'd shot his wife",
#  'sent them to prison',
#  'crying her eyes out',
#  'last monday',
#  'put on weight',
#  'what had happened',
#  "he'd saved the woman",
#  'become too fat',
#  'what had happened',
#  'in holidays today',
#  'photographs of footprints',
#  'which cannot be explained',
#  "it's a wolf",
#  "they aren't discovered",
#  'to photograph these things',
#  'an unborn child',
#  'the mysterious beach',
#  'choosing between',
#  'it represents the',
#  'it is ridiculous that',
#  'is scientifically proved',
#  'there are advertisements for',
#  'it was my imagination',
#  'to ban smoking',
#  'my happiness depends on',
#  'the pleasant smell of',
#  'dialling the number',
#  'actually i had no',
#  'the most tiring part',
#  'gamblers play poker',
#  'the existence of',
#  'physical sensations',
#  'it is without doubt',
#  'let us analyse',
#  'developing countries',
#  'i personally believe',
#  'as often as i breathe',
#  'flowers, perfumes',
#  "to interpret what i've said",
#  'my stomach hurt',
#  'surprised and paralysed by',
#  'i believe it was',
#  'when it occurred',
#  'she asked us whether',
#  'an extremely hot day',
#  'be able to choose',
#  'their opinion about',
#  'to think what',
#  'to continue with',
#  'it was quite successful',
#  'i never thought that',
#  "i'd heard that",
#  'he obviously reckoned',
#  'to praise him',
#  'screaming louder than',
#  'to absorb it',
#  "i couldn't stop staring",
#  'a street cafe',
#  'a movie was shown',
#  'companies started to work',
#  'there is',
#  'a tendency to',
#  'meet in the snack-bar',
#  'security control',
#  'in contact with']

# %% [markdown]
# ### calculate hits

# %%
same_count = 0
hits = 0
corrections = 0
final_output_wordList = []
for string_output, truth,error in zip(final_output,cleaned_correct,clean_error):
    for word_output, word_truth,word_error in zip(string_output.split(),truth.split(),error.split()):
        if word_output == word_truth and word_output != word_error:
            hits +=1 
            corrections += 1
        elif word_output != word_error:
            corrections += 1

# %%
print "hit:",hits
print "correcitons:",corrections
# Out:
# hit: 100
# correcitons: 141

# %%
precision = float(hits)/corrections
recall = float(hits)/183
falsealarm = float(corrections-hits)/corrections
print "Precision:", precision
print "Recall:", recall#we have total 183 errors
print "FalseAlarm:",falsealarm
# Out:
#  Precision: 0.709219858156
# Recall: 0.546448087432
# FalseAlarm: 0.290780141844

# %%
print "F1-score:" ,2 *precision*recall / (precision+recall)
# Out:
# F1-score: 0.617283950617

# %% [markdown]
# ## Challenges

# %% [markdown]
# 1. In the begining, it tooks lots of time to correct the sentences since Netspeak was slow. After Teacher released Linggle API, I felt comfortable correcting the sentences!
# 2. Some words were not in the big.text. So even if Linggle is powerful, it couldn't be fed by some other potential candidates. Therefore, I added text from brown corpus. The performance was a little bit improved.
# 3. Considering confusable words is useful.
